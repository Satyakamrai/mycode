# %%
# import pandas, pd is an alias
import pandas as pd
import numpy as np

# Creating a numeric pandas series
s = pd.Series([2, 4, 5, 6, 9])
print(s)
print(type(s))
# Out:
# 0    2
# 1    4
# 2    5
# 3    6
# 4    9
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
# keys become column names
import pandas as pd
import numpy as np
df = pd.DataFrame({'name': ['Vinay', 'Kushal', 'Aman', 'Saif'], 
                   'age': [22, 25, 24, 28], 
                    'occupation': ['engineer', 'doctor', 'data analyst', 'teacher']})
df
# Out:
#      name  age    occupation
# 0   Vinay   22      engineer
# 1  Kushal   25        doctor
# 2    Aman   24  data analyst
# 3    Saif   28       teacher

# %%
import numpy as np
import pandas as pd
#list1 = [2,3,4]
series_1 = pd.Series([2,3,4])
#series_2 = pd.Series(list(map(lambda x :x**2, series_1)))
series_2 = series_1.apply(lambda x:x**2)
print(series_1)
print(series_2)
# Out:
# 0    2
# 1    3
# 2    4
# dtype: int64
# 0     4
# 1     9
# 2    16
# dtype: int64

# %%
# keys become column names
import pandas as pd
import numpy as np
df = pd.DataFrame({'name': ['Vinay', 'Kushal', 'Aman', 'Saif'], 
                   'age': [22, 25, 24, 28], 
                    'occupation': ['engineer', 'doctor', 'data analyst', 'teacher']})
describe(df) 
columns(df)
shape(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2733cd2a73da> in <module>
#       5                    'age': [22, 25, 24, 28],
#       6                     'occupation': ['engineer', 'doctor', 'data analyst', 'teacher']})
# ----> 7 describe(df)
#       8 columns(df)
#       9 shape(df)
#
# NameError: name 'describe' is not defined

# %%
market_df.shape
# Out:
# (517, 13)

# %%
# Read the variable from STDIN
n = int(input())

import numpy as np 
import pandas as pd 

series_1 = pd.Series(np.array(range(1,n+1))**2, index = range(1,n+1))
print(series_1)
# Out:
# 4
# 1     1
# 2     4
# 3     9
# 4    16
# dtype: int32

# %%
# keys become column names
import pandas as pd
import numpy as np
df = pd.DataFrame({'name': ['Vinay', 'Kushal', 'Aman', 'Saif'], 
                   'age': [22, 25, 24, 28], 
                    'occupation': ['engineer', 'doctor', 'data analyst', 'teacher']})

# %%
df.describe()
# Out:
#          age
# count   4.00
# mean   24.75
# std     2.50
# min    22.00
# 25%    23.50
# 50%    24.50
# 75%    25.75
# max    28.00

# %%
df.shape
# Out:
# (4, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
# name          4 non-null object
# age           4 non-null int64
# occupation    4 non-null object
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
df.columns
# Out:
# Index(['name', 'age', 'occupation'], dtype='object')

# %%
# reading a CSV file as a dataframe
market_df = pd.read_csv("https://query.data.world/s/vBDCsoHCytUSLKkLvq851k2b8JOCkF")

# %%
market_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 13 columns):
# X        517 non-null int64
# Y        517 non-null int64
# month    517 non-null object
# day      517 non-null object
# FFMC     517 non-null float64
# DMC      517 non-null float64
# DC       517 non-null float64
# ISI      517 non-null float64
# temp     517 non-null float64
# RH       517 non-null int64
# wind     517 non-null float64
# rain     517 non-null float64
# area     517 non-null float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 52.6+ KB

# %%
market_df.values
# Out:
# array([[7, 5, 'mar', ..., 6.7, 0.0, 0.0],
#        [7, 4, 'oct', ..., 0.9, 0.0, 0.0],
#        [7, 4, 'oct', ..., 1.3, 0.0, 0.0],
#        ...,
#        [7, 4, 'aug', ..., 6.7, 0.0, 11.16],
#        [1, 4, 'aug', ..., 4.0, 0.0, 0.0],
#        [6, 3, 'nov', ..., 4.5, 0.0, 0.0]], dtype=object)

# %%
market_df.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
market_df.shape
# Out:
# (517, 13)

# %%
market_df.set_index('X', inplace = True)
market_df.head()
# Out:
#    Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# X
# 7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
#Sort the columns 
market_df.sort_index(axis = 1, ascending = True)
# Out:
#        DC    DMC  FFMC   ISI  RH  Y   area  day month  rain  temp  wind
# X
# 7    94.3   26.2  86.2   5.1  51  5   0.00  fri   mar   0.0   8.2   6.7
# 7   669.1   35.4  90.6   6.7  33  4   0.00  tue   oct   0.0  18.0   0.9
# 7   686.9   43.7  90.6   6.7  33  4   0.00  sat   oct   0.0  14.6   1.3
# 8    77.5   33.3  91.7   9.0  97  6   0.00  fri   mar   0.2   8.3   4.0
# 8   102.2   51.3  89.3   9.6  99  6   0.00  sun   mar   0.0  11.4   1.8
# ..    ...    ...   ...   ...  .. ..    ...  ...   ...   ...   ...   ...
# 4   665.6   56.7  81.6   1.9  32  3   6.44  sun   aug   0.0  27.8   2.7
# 2   665.6   56.7  81.6   1.9  71  4  54.29  sun   aug   0.0  21.9   5.8
# 7   665.6   56.7  81.6   1.9  70  4  11.16  sun   aug   0.0  21.2   6.7
# 1   614.7  146.0  94.4  11.3  42  4   0.00  sat   aug   0.0  25.6   4.0
# 6   106.7    3.0  79.5   1.1  31  3   0.00  tue   nov   0.0  11.8   4.5
#
# [517 rows x 12 columns]

# %%
import numpy as np
import pandas as pd

market_df = pd.read_csv("global_sales_data/market_fact.csv")
market_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
market_df[2:7]
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.76      0.01               5
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38
# 5   -47.64           6.15                 0.37
# 6     1.32           0.50                 0.36

# %%
market_df[['Ord_id', 'Prod_id']].head(20)
print(type(market_df['Ord_id']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df_2 = market_df[['Ord_id', 'Prod_id']].head(20)
print(type(df_2))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/vBDCsoHCytUSLKkLvq851k2b8JOCkF')
df_2 = #Type your code here for indexing the dataframe
print(df_2.head(20))
# Out:
#     X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area
# 0   7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.0
# 1   7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.0
# 2   7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.0
# 3   8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.0
# 4   8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.0
# 5   8  6   aug  sun  92.3   85.3  488.0  14.7  22.2  29   5.4   0.0   0.0
# 6   8  6   aug  mon  92.3   88.9  495.6   8.5  24.1  27   3.1   0.0   0.0
# 7   8  6   aug  mon  91.5  145.4  608.2  10.7   8.0  86   2.2   0.0   0.0
# 8   8  6   sep  tue  91.0  129.5  692.6   7.0  13.1  63   5.4   0.0   0.0
# 9   7  5   sep  sat  92.5   88.0  698.6   7.1  22.8  40   4.0   0.0   0.0
# 10  7  5   sep  sat  92.5   88.0  698.6   7.1  17.8  51   7.2   0.0   0.0
# 11  7  5   sep  sat  92.8   73.2  713.0  22.6  19.3  38   4.0   0.0   0.0
# 12  6  5   aug  fri  63.5   70.8  665.3   0.8  17.0  72   6.7   0.0   0.0
# 13  6  5   sep  mon  90.9  126.5  686.5   7.0  21.3  42   2.2   0.0   0.0
# 14  6  5   sep  wed  92.9  133.3  699.6   9.2  26.4  21   4.5   0.0   0.0
# 15  6  5   sep  fri  93.3  141.2  713.9  13.9  22.9  44   5.4   0.0   0.0
# 16  5  5   mar  sat  91.7   35.8   80.8   7.8  15.1  27   5.4   0.0   0.0
# 17  8  5   oct  mon  84.9   32.8  664.2   3.0  16.7  47   4.9   0.0   0.0
# 18  6  4   mar  wed  89.2   27.9   70.8   6.3  15.9  35   4.0   0.0   0.0
# 19  6  4   apr  sat  86.3   27.4   97.1   5.1   9.3  44   4.5   0.0   0.0

# %%
market_df.loc[2, 'Sales']
# Out:
# 4701.69

# %%
market_df.iloc[[2], 4]
# Out:
# 2    4701.69
# Name: Sales, dtype: float64

# %%
# loading libraries and reading the data
import numpy as np
import pandas as pd

market_df = pd.read_csv("./global_sales_data/market_fact.csv")
customer_df = pd.read_csv("./global_sales_data/cust_dimen.csv")
product_df = pd.read_csv("./global_sales_data/prod_dimen.csv")
shipping_df = pd.read_csv("./global_sales_data/shipping_dimen.csv")
orders_df = pd.read_csv("./global_sales_data/orders_dimen.csv")

# %%
print(market_df.shape)
print(customer_df.shape)
print(product_df.shape)
print(shipping_df.shape)
print(orders_df.shape)
# Out:
# (8399, 10)
# (1832, 5)
# (17, 3)
# (7701, 4)
# (5506, 4)

# %%
# Merging the dataframes
# Note that Cust_id is the common column/key, which is provided to the 'on' argument
# how = 'inner' makes sure that only the customer ids present in both dfs are included in the result
df_1 = pd.merge(market_df, customer_df, how='inner', on='Cust_id')
print(df_1.head(10))
print(df_1.shape)
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 7  Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8  Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
# 9  Ord_4725   Prod_6  SHP_6593  Cust_1641    57.2200      0.07
#
#    Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  Customer_Name  \
# 0              23   -30.51           3.60                 0.56  AARON BERGMAN
# 1              13     4.56           0.93                 0.54  AARON BERGMAN
# 2              26  1148.90           2.50                 0.59  AARON BERGMAN
# 3              43   729.34          14.30                 0.37  AARON BERGMAN
# 4              35  1219.87          26.30                 0.38  AARON BERGMAN
# 5              23   -47.64           6.15                 0.37  AARON BERGMAN
# 6               5     1.32           0.50                 0.36  AARON BERGMAN
# 7              48  1137.91           0.99                 0.55  AARON HAWKINS
# 8              33    45.84           0.71                 0.52  AARON HAWKINS
# 9               8   -27.72           6.60                 0.37  AARON HAWKINS
#
#            Province   Region Customer_Segment
# 0           ALBERTA     WEST        CORPORATE
# 1           ALBERTA     WEST        CORPORATE
# 2           ALBERTA     WEST        CORPORATE
# 3           ALBERTA     WEST        CORPORATE
# 4           ALBERTA     WEST        CORPORATE
# 5           ALBERTA     WEST        CORPORATE
# 6           NUNAVUT  NUNAVUT        CORPORATE
# 7  BRITISH COLUMBIA     WEST      HOME OFFICE
# 8  BRITISH COLUMBIA     WEST      HOME OFFICE
# 9  BRITISH COLUMBIA     WEST      HOME OFFICE
# (8399, 14)

# %%
# Example 2: Select all orders from product category = office supplies and from the corporate segment
# We now need to merge the product_df

df_2 = pd.merge(df_1, product_df, how='inner', on='Prod_id')
df_2.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id   Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818  136.81      0.01              23
# 1  Ord_2978  Prod_16  SHP_4112  Cust_1088  305.05      0.04              27
# 2  Ord_5484  Prod_16  SHP_7663  Cust_1820  322.82      0.05              35
# 3  Ord_3730  Prod_16  SHP_5175  Cust_1314  459.08      0.04              34
# 4  Ord_4143  Prod_16  SHP_5771  Cust_1417  207.21      0.06              24
#
#    Profit  Shipping_Cost  Product_Base_Margin        Customer_Name  \
# 0  -30.51           3.60                 0.56        AARON BERGMAN
# 1   23.12           3.37                 0.57        AARON HAWKINS
# 2  -17.58           3.98                 0.56         ADRIAN SHAMI
# 3   61.57           3.14                 0.60  ALEKSANDRA GANNAWAY
# 4  -78.64           6.14                 0.59         ALLEN ARMOLD
#
#         Province    Region Customer_Segment Product_Category  \
# 0        ALBERTA      WEST        CORPORATE  OFFICE SUPPLIES
# 1        ONTARIO   ONTARIO      HOME OFFICE  OFFICE SUPPLIES
# 2        ALBERTA      WEST         CONSUMER  OFFICE SUPPLIES
# 3    SASKACHEWAN    PRARIE        CORPORATE  OFFICE SUPPLIES
# 4  NEW BRUNSWICK  ATLANTIC      HOME OFFICE  OFFICE SUPPLIES
#
#             Product_Sub_Category
# 0  SCISSORS, RULERS AND TRIMMERS
# 1  SCISSORS, RULERS AND TRIMMERS
# 2  SCISSORS, RULERS AND TRIMMERS
# 3  SCISSORS, RULERS AND TRIMMERS
# 4  SCISSORS, RULERS AND TRIMMERS

# %%
# Select all orders from product category = office supplies and from the corporate segment
df_2.loc[(df_2['Product_Category']=='OFFICE SUPPLIES') & (df_2['Customer_Segment']=='CORPORATE'),:]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01
# 3     Ord_3730  Prod_16  SHP_5175  Cust_1314   459.08      0.04
# 7     Ord_4506  Prod_16  SHP_6273  Cust_1544    92.02      0.07
# 9     Ord_1551  Prod_16  SHP_2145   Cust_531   184.77      0.00
# 11    Ord_1429  Prod_16  SHP_1976   Cust_510   539.06      0.05
# ...        ...      ...       ...        ...      ...       ...
# 7545  Ord_4629   Prod_1  SHP_6447  Cust_1587   848.19      0.06
# 7546  Ord_4604   Prod_1  SHP_6403  Cust_1522   234.24      0.09
# 7551  Ord_3543   Prod_1  SHP_4905  Cust_1266  1184.11      0.07
# 7552  Ord_2722   Prod_1  SHP_3731  Cust_1006  3508.33      0.04
# 7553  Ord_4424   Prod_1  SHP_6165  Cust_1519   994.04      0.03
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin  \
# 0                 23  -30.51           3.60                 0.56
# 3                 34   61.57           3.14                 0.60
# 7                  9  -24.88           4.68                 0.59
# 9                 29  -71.96           5.30                 0.55
# 11                42 -123.07           4.59                 0.82
# ...              ...     ...            ...                  ...
# 7545              25  120.02           5.49                 0.60
# 7546              24 -151.80           9.45                 0.60
# 7551               6 -145.07          19.99                 0.71
# 7552              21 -546.98          35.00                 0.85
# 7553              10 -335.06          35.00                  NaN
#
#             Customer_Name          Province   Region Customer_Segment  \
# 0           AARON BERGMAN           ALBERTA     WEST        CORPORATE
# 3     ALEKSANDRA GANNAWAY       SASKACHEWAN   PRARIE        CORPORATE
# 7                 AMY COX             YUKON    YUKON        CORPORATE
# 9              ANDY YOTOV           ONTARIO  ONTARIO        CORPORATE
# 11          ANNA HABERLIN           ONTARIO  ONTARIO        CORPORATE
# ...                   ...               ...      ...              ...
# 7545     VICTORIA PISTEKA  BRITISH COLUMBIA     WEST        CORPORATE
# 7546     VICTORIA PISTEKA             YUKON    YUKON        CORPORATE
# 7551        WILLIAM BROWN       SASKACHEWAN   PRARIE        CORPORATE
# 7552         XYLONA PRICE           ONTARIO  ONTARIO        CORPORATE
# 7553        YANA SORENSEN             YUKON    YUKON        CORPORATE
#
#      Product_Category           Product_Sub_Category
# 0     OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 3     OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 7     OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 9     OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 11    OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# ...               ...                            ...
# 7545  OFFICE SUPPLIES         STORAGE & ORGANIZATION
# 7546  OFFICE SUPPLIES         STORAGE & ORGANIZATION
# 7551  OFFICE SUPPLIES         STORAGE & ORGANIZATION
# 7552  OFFICE SUPPLIES         STORAGE & ORGANIZATION
# 7553  OFFICE SUPPLIES         STORAGE & ORGANIZATION
#
# [1680 rows x 16 columns]

# %%
# dataframes having the same columns
df1 = pd.DataFrame({'Name': ['Aman', 'Joy', 'Rashmi', 'Saif'],
                    'Age': ['34', '31', '22', '33'],
                    'Gender': ['M', 'M', 'F', 'M']}
                  )

df2 = pd.DataFrame({'Name': ['Akhil', 'Asha', 'Preeti'],
                    'Age': ['31', '22', '23'],
                    'Gender': ['M', 'F', 'F']}
                  )
df1
# Out:
#      Name Age Gender
# 0    Aman  34      M
# 1     Joy  31      M
# 2  Rashmi  22      F
# 3    Saif  33      M

# %%
df2
# Out:
#      Name Age Gender
# 0   Akhil  31      M
# 1    Asha  22      F
# 2  Preeti  23      F

# %%
pd.concat([df1, df2], axis = 0)
# Out:
#      Name Age Gender
# 0    Aman  34      M
# 1     Joy  31      M
# 2  Rashmi  22      F
# 3    Saif  33      M
# 0   Akhil  31      M
# 1    Asha  22      F
# 2  Preeti  23      F

# %%
df1.append(df2)
# Out:
#      Name Age Gender
# 0    Aman  34      M
# 1     Joy  31      M
# 2  Rashmi  22      F
# 3    Saif  33      M
# 0   Akhil  31      M
# 1    Asha  22      F
# 2  Preeti  23      F

# %%
pd.concat([df1, df2], axis = 1)
# Out:
#      Name Age Gender    Name  Age Gender
# 0    Aman  34      M   Akhil   31      M
# 1     Joy  31      M    Asha   22      F
# 2  Rashmi  22      F  Preeti   23      F
# 3    Saif  33      M     NaN  NaN    NaN

# %%
import pandas as pd
df_1 = pd.read_csv('https://query.data.world/s/vv3snq28bp0TJq2ggCdxGOghEQKPZo')
df_2 = pd.read_csv('https://query.data.world/s/9wVKjNT0yiRc3YbVJaiI8a6HGl2d74')
df_3 =(df_1.append(df_2)).sort_index(axis = 1, ascending = True)
print(df_3.head())
# Out:
#                       address address_2             city city_2  \
# 0   "435 s. la cienega blvd."       NaN    "los angeles"    NaN
# 1       "12224 ventura blvd."       NaN    "studio city"    NaN
# 2      "701 stone canyon rd."       NaN        "bel air"    NaN
# 3       "14016 ventura blvd."       NaN   "sherman oaks"    NaN
# 4       "624 s. la brea ave."       NaN    "los angeles"    NaN
#
#             cuisine cuisine_2                       name name_2 unique_id
# 0     "steakhouses"       NaN  arnie morton's of chicago    NaN       '0'
# 1           "delis"       NaN                 art's deli    NaN       '1'
# 2     "californian"       NaN              bel-air hotel    NaN       '2'
# 3   "french bistro"       NaN                 cafe bizou    NaN       '3'
# 4     "californian"       NaN                  campanile    NaN       '4'

# %%
import pandas as pd
df_1 = pd.read_csv('https://query.data.world/s/vv3snq28bp0TJq2ggCdxGOghEQKPZo')
df_2 = pd.read_csv('https://query.data.world/s/9wVKjNT0yiRc3YbVJaiI8a6HGl2d74')
df_3 =(df_1.sort_index(axis = 1, ascending = True)).append(df_2.sort_index(axis = 1, ascending = True))
print(df_3.head())
# Out:
#                       address address_2             city city_2  \
# 0   "435 s. la cienega blvd."       NaN    "los angeles"    NaN
# 1       "12224 ventura blvd."       NaN    "studio city"    NaN
# 2      "701 stone canyon rd."       NaN        "bel air"    NaN
# 3       "14016 ventura blvd."       NaN   "sherman oaks"    NaN
# 4       "624 s. la brea ave."       NaN    "los angeles"    NaN
#
#             cuisine cuisine_2                       name name_2 unique_id
# 0     "steakhouses"       NaN  arnie morton's of chicago    NaN       '0'
# 1           "delis"       NaN                 art's deli    NaN       '1'
# 2     "californian"       NaN              bel-air hotel    NaN       '2'
# 3   "french bistro"       NaN                 cafe bizou    NaN       '3'
# 4     "californian"       NaN                  campanile    NaN       '4'

# %%
# Teamwise stats for IPL 2018
IPL_2018 = pd.DataFrame({'IPL Team': ['CSK', 'SRH', 'KKR', 'RR', 'MI', 'RCB', 'KXIP', 'DD'],
                         'Matches Played': [16, 17, 16, 15, 14, 14, 14, 14],
                         'Matches Won': [11, 10, 9, 7, 6, 6, 6, 5]}
                       )

# Set the 'IPL Team' column as the index to perform arithmetic operations on the other rows using the team as reference
IPL_2018.set_index('IPL Team', inplace = True)
IPL_2018
# Out:
#           Matches Played  Matches Won
# IPL Team
# CSK                   16           11
# SRH                   17           10
# KKR                   16            9
# RR                    15            7
# MI                    14            6
# RCB                   14            6
# KXIP                  14            6
# DD                    14            5

# %%
print(IPL_2018)
# Out:
#           Matches Played  Matches Won
# IPL Team
# CSK                   16           11
# SRH                   17           10
# KKR                   16            9
# RR                    15            7
# MI                    14            6
# RCB                   14            6
# KXIP                  14            6
# DD                    14            5

# %%
# Similarly, we have the stats for IPL 2017
IPL_2017 = pd.DataFrame({'IPL Team': ['MI', 'RPS', 'KKR', 'SRH', 'KXIP', 'DD', 'GL', 'RCB'],
                         'Matches Played': [17, 16, 16, 15, 14, 14, 14, 14],
                         'Matches Won': [12, 10, 9, 8, 7, 6, 4, 3]}
                       )
IPL_2017.set_index('IPL Team', inplace = True)
IPL_2017
# Out:
#           Matches Played  Matches Won
# IPL Team
# MI                    17           12
# RPS                   16           10
# KKR                   16            9
# SRH                   15            8
# KXIP                  14            7
# DD                    14            6
# GL                    14            4
# RCB                   14            3

# %%
Total = IPL_2018 + IPL_2017
Total
# Out:
#           Matches Played  Matches Won
# IPL Team
# CSK                  NaN          NaN
# DD                  28.0         11.0
# GL                   NaN          NaN
# KKR                 32.0         18.0
# KXIP                28.0         13.0
# MI                  31.0         18.0
# RCB                 28.0          9.0
# RPS                  NaN          NaN
# RR                   NaN          NaN
# SRH                 32.0         18.0

# %%
# The fill_value argument inside the df.add() function replaces all the NaN values in the two dataframes w.r.t. each other with zero.
Total = IPL_2018.add(IPL_2017, fill_value = 0)
Total
# Out:
#           Matches Played  Matches Won
# IPL Team
# CSK                 16.0         11.0
# DD                  28.0         11.0
# GL                  14.0          4.0
# KKR                 32.0         18.0
# KXIP                28.0         13.0
# MI                  31.0         18.0
# RCB                 28.0          9.0
# RPS                 16.0         10.0
# RR                  15.0          7.0
# SRH                 32.0         18.0

# %%
# Creating a new column - 'Win Percentage'

Total['Win Percentage'] = Total['Matches Won']/Total['Matches Played']
Total
# Out:
#           Matches Played  Matches Won  Win Percentage
# IPL Team
# CSK                 16.0         11.0        0.687500
# DD                  28.0         11.0        0.392857
# GL                  14.0          4.0        0.285714
# KKR                 32.0         18.0        0.562500
# KXIP                28.0         13.0        0.464286
# MI                  31.0         18.0        0.580645
# RCB                 28.0          9.0        0.321429
# RPS                 16.0         10.0        0.625000
# RR                  15.0          7.0        0.466667
# SRH                 32.0         18.0        0.562500

# %%
# Sorting to determine the teams with most number of wins. If the number of wins of two teams are the same, sort by the win percentage.

Total.sort_values(by = ['Matches Won', 'Win Percentage'], ascending = False)
# Out:
#           Matches Played  Matches Won  Win Percentage
# IPL Team
# MI                  31.0         18.0        0.580645
# KKR                 32.0         18.0        0.562500
# SRH                 32.0         18.0        0.562500
# KXIP                28.0         13.0        0.464286
# CSK                 16.0         11.0        0.687500
# DD                  28.0         11.0        0.392857
# RPS                 16.0         10.0        0.625000
# RCB                 28.0          9.0        0.321429
# RR                  15.0          7.0        0.466667
# GL                  14.0          4.0        0.285714

# %%
import numpy as np 
import pandas as pd

# Defining the three dataframes indicating the gold, silver, and bronze medal counts
# of different countries
gold = pd.DataFrame({'Country': ['USA', 'France', 'Russia'],
                         'Medals': [15, 13, 9]}
                    )
silver = pd.DataFrame({'Country': ['USA', 'Germany', 'Russia'],
                        'Medals': [29, 20, 16]}
                    )
bronze = pd.DataFrame({'Country': ['France', 'USA', 'UK'],
                        'Medals': [40, 28, 27]}
                    )

total = (gold.append(silver)).append(bronze)
print(total)
# Out:
#    Country  Medals
# 0      USA      15
# 1   France      13
# 2   Russia       9
# 0      USA      29
# 1  Germany      20
# 2   Russia      16
# 0   France      40
# 1      USA      28
# 2       UK      27

# %%
import numpy as np 
import pandas as pd

# Defining the three dataframes indicating the gold, silver, and bronze medal counts
# of different countries
gold = pd.DataFrame({'Country': ['USA', 'France', 'Russia'],
                         'Medals': [15, 13, 9]}
                    )
silver = pd.DataFrame({'Country': ['USA', 'Germany', 'Russia'],
                        'Medals': [29, 20, 16]}
                    )
bronze = pd.DataFrame({'Country': ['France', 'USA', 'UK'],
                        'Medals': [40, 28, 27]}
                    )
gold.set_index('Country', inplace = True)
silver.set_index('Country', inplace = True)
bronze.set_index('Country', inplace = True)

total_1 = gold.add(silver, fill_value = 0)
final = total_1.add(bronze, fill_value = 0)
final.sort_values(by = (['Medals']), ascending = False)
# Out:
#          Medals
# Country
# France     53.0
# Germany    20.0
# Russia     25.0
# UK         27.0
# USA        72.0

# %%
# Loading libraries and files
import numpy as np
import pandas as pd

market_df = pd.read_csv("global_sales_data/market_fact.csv")
customer_df = pd.read_csv("global_sales_data/cust_dimen.csv")
product_df = pd.read_csv("global_sales_data/prod_dimen.csv")
shipping_df = pd.read_csv("global_sales_data/shipping_dimen.csv")
orders_df = pd.read_csv("global_sales_data/orders_dimen.csv")

# %%
# Merging the dataframes one by one
df_1 = pd.merge(market_df, customer_df, how='inner', on='Cust_id')
df_2 = pd.merge(df_1, product_df, how='inner', on='Prod_id')
df_3 = pd.merge(df_2, shipping_df, how='inner', on='Ship_id')
master_df = pd.merge(df_3, orders_df, how='inner', on='Ord_id')

master_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 2  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 3  Ord_2978  Prod_16  SHP_4112  Cust_1088   305.05      0.04              27
# 4  Ord_5484  Prod_16  SHP_7663  Cust_1820   322.82      0.05              35
#
#     Profit  Shipping_Cost  Product_Base_Margin  ...   Region Customer_Segment  \
# 0   -30.51           3.60                 0.56  ...     WEST        CORPORATE
# 1  1148.90           2.50                 0.59  ...     WEST        CORPORATE
# 2   -47.64           6.15                 0.37  ...     WEST        CORPORATE
# 3    23.12           3.37                 0.57  ...  ONTARIO      HOME OFFICE
# 4   -17.58           3.98                 0.56  ...     WEST         CONSUMER
#
#   Product_Category           Product_Sub_Category Order_ID_x    Ship_Mode  \
# 0  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      36262  REGULAR AIR
# 1       TECHNOLOGY   TELEPHONES AND COMMUNICATION      36262  EXPRESS AIR
# 2  OFFICE SUPPLIES                          PAPER      36262  EXPRESS AIR
# 3  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      37863  REGULAR AIR
# 4  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      53026  REGULAR AIR
#
#     Ship_Date Order_ID_y  Order_Date  Order_Priority
# 0  28-07-2010      36262  27-07-2010   NOT SPECIFIED
# 1  27-07-2010      36262  27-07-2010   NOT SPECIFIED
# 2  28-07-2010      36262  27-07-2010   NOT SPECIFIED
# 3  26-02-2011      37863  24-02-2011            HIGH
# 4  03-03-2012      53026  26-02-2012             LOW
#
# [5 rows x 22 columns]

# %%
# Which customer segments are the least profitable? 

# Step 1. Grouping: First, we will group the dataframe by customer segments
df_by_segment = master_df.groupby('Customer_Segment')
df_by_segment

# %%
# Step 2. Applying a function
# We can choose aggregate functions such as sum, mean, median, etc.
df_by_segment['Profit'].sum()
# Out:
# Customer_Segment
# CONSUMER          287959.94
# CORPORATE         599746.00
# HOME OFFICE       318354.03
# SMALL BUSINESS    315708.01
# Name: Profit, dtype: float64

# %%
# Alternatively
df_by_segment.Profit.sum()
# Out:
# Customer_Segment
# CONSUMER          287959.94
# CORPORATE         599746.00
# HOME OFFICE       318354.03
# SMALL BUSINESS    315708.01
# Name: Profit, dtype: float64

# %%
# For better readability, you may want to sort the summarised series:
df_by_segment.Profit.sum().sort_values(ascending = False)
# Out:
# Customer_Segment
# CORPORATE         599746.00
# HOME OFFICE       318354.03
# SMALL BUSINESS    315708.01
# CONSUMER          287959.94
# Name: Profit, dtype: float64

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/vBDCsoHCytUSLKkLvq851k2b8JOCkF')
tmp = df.groupby(['month', 'day'])
df_1 = tmp['rain','wind'].mean()
print(df_1.head(20))
# Out:
#                rain      wind
# month day
# apr   fri  0.000000  3.100000
#       mon  0.000000  3.100000
#       sat  0.000000  4.500000
#       sun  0.000000  5.666667
#       thu  0.000000  5.800000
#       wed  0.000000  2.700000
# aug   fri  0.066667  4.766667
#       mon  0.000000  2.873333
#       sat  0.000000  4.310345
#       sun  0.025000  4.417500
#       thu  0.000000  3.503846
#       tue  0.300000  4.567857
#       wed  0.000000  3.520000
# dec   fri  0.000000  4.900000
#       mon  0.000000  8.500000
#       sun  0.000000  8.500000
#       thu  0.000000  4.900000
#       tue  0.000000  8.500000
#       wed  0.000000  8.000000
# feb   fri  0.000000  4.820000

# %%
# Loading libraries and files
import numpy as np
import pandas as pd

market_df = pd.read_csv("global_sales_data/market_fact.csv")
customer_df = pd.read_csv("global_sales_data/cust_dimen.csv")
product_df = pd.read_csv("global_sales_data/prod_dimen.csv")
shipping_df = pd.read_csv("global_sales_data/shipping_dimen.csv")
orders_df = pd.read_csv("global_sales_data/orders_dimen.csv")

# Merging the dataframes to create a master_df
df_1 = pd.merge(market_df, customer_df, how='inner', on='Cust_id')
df_2 = pd.merge(df_1, product_df, how='inner', on='Prod_id')
df_3 = pd.merge(df_2, shipping_df, how='inner', on='Ship_id')
master_df = pd.merge(df_3, orders_df, how='inner', on='Ord_id')

master_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 2  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 3  Ord_2978  Prod_16  SHP_4112  Cust_1088   305.05      0.04              27
# 4  Ord_5484  Prod_16  SHP_7663  Cust_1820   322.82      0.05              35
#
#     Profit  Shipping_Cost  Product_Base_Margin  ...   Region Customer_Segment  \
# 0   -30.51           3.60                 0.56  ...     WEST        CORPORATE
# 1  1148.90           2.50                 0.59  ...     WEST        CORPORATE
# 2   -47.64           6.15                 0.37  ...     WEST        CORPORATE
# 3    23.12           3.37                 0.57  ...  ONTARIO      HOME OFFICE
# 4   -17.58           3.98                 0.56  ...     WEST         CONSUMER
#
#   Product_Category           Product_Sub_Category Order_ID_x    Ship_Mode  \
# 0  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      36262  REGULAR AIR
# 1       TECHNOLOGY   TELEPHONES AND COMMUNICATION      36262  EXPRESS AIR
# 2  OFFICE SUPPLIES                          PAPER      36262  EXPRESS AIR
# 3  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      37863  REGULAR AIR
# 4  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      53026  REGULAR AIR
#
#     Ship_Date Order_ID_y  Order_Date  Order_Priority
# 0  28-07-2010      36262  27-07-2010   NOT SPECIFIED
# 1  27-07-2010      36262  27-07-2010   NOT SPECIFIED
# 2  28-07-2010      36262  27-07-2010   NOT SPECIFIED
# 3  26-02-2011      37863  24-02-2011            HIGH
# 4  03-03-2012      53026  26-02-2012             LOW
#
# [5 rows x 22 columns]

# %%
# Create a function to be applied
def is_positive(x):
    return x > 0

# Create a new column
master_df['is_profitable'] = master_df['Profit'].apply(is_positive)
master_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 2  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 3  Ord_2978  Prod_16  SHP_4112  Cust_1088   305.05      0.04              27
# 4  Ord_5484  Prod_16  SHP_7663  Cust_1820   322.82      0.05              35
#
#     Profit  Shipping_Cost  Product_Base_Margin  ... Customer_Segment  \
# 0   -30.51           3.60                 0.56  ...        CORPORATE
# 1  1148.90           2.50                 0.59  ...        CORPORATE
# 2   -47.64           6.15                 0.37  ...        CORPORATE
# 3    23.12           3.37                 0.57  ...      HOME OFFICE
# 4   -17.58           3.98                 0.56  ...         CONSUMER
#
#   Product_Category           Product_Sub_Category Order_ID_x    Ship_Mode  \
# 0  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      36262  REGULAR AIR
# 1       TECHNOLOGY   TELEPHONES AND COMMUNICATION      36262  EXPRESS AIR
# 2  OFFICE SUPPLIES                          PAPER      36262  EXPRESS AIR
# 3  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      37863  REGULAR AIR
# 4  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      53026  REGULAR AIR
#
#     Ship_Date  Order_ID_y  Order_Date Order_Priority  is_profitable
# 0  28-07-2010       36262  27-07-2010  NOT SPECIFIED          False
# 1  27-07-2010       36262  27-07-2010  NOT SPECIFIED           True
# 2  28-07-2010       36262  27-07-2010  NOT SPECIFIED          False
# 3  26-02-2011       37863  24-02-2011           HIGH           True
# 4  03-03-2012       53026  26-02-2012            LOW          False
#
# [5 rows x 23 columns]

# %%
# Create a new column using a lambda function, same as above function
master_df['is_profitable'] = master_df['Profit'].apply(lambda x: x > 0)
master_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 2  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 3  Ord_2978  Prod_16  SHP_4112  Cust_1088   305.05      0.04              27
# 4  Ord_5484  Prod_16  SHP_7663  Cust_1820   322.82      0.05              35
#
#     Profit  Shipping_Cost  Product_Base_Margin  ... Customer_Segment  \
# 0   -30.51           3.60                 0.56  ...        CORPORATE
# 1  1148.90           2.50                 0.59  ...        CORPORATE
# 2   -47.64           6.15                 0.37  ...        CORPORATE
# 3    23.12           3.37                 0.57  ...      HOME OFFICE
# 4   -17.58           3.98                 0.56  ...         CONSUMER
#
#   Product_Category           Product_Sub_Category Order_ID_x    Ship_Mode  \
# 0  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      36262  REGULAR AIR
# 1       TECHNOLOGY   TELEPHONES AND COMMUNICATION      36262  EXPRESS AIR
# 2  OFFICE SUPPLIES                          PAPER      36262  EXPRESS AIR
# 3  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      37863  REGULAR AIR
# 4  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      53026  REGULAR AIR
#
#     Ship_Date  Order_ID_y  Order_Date Order_Priority  is_profitable
# 0  28-07-2010       36262  27-07-2010  NOT SPECIFIED          False
# 1  27-07-2010       36262  27-07-2010  NOT SPECIFIED           True
# 2  28-07-2010       36262  27-07-2010  NOT SPECIFIED          False
# 3  26-02-2011       37863  24-02-2011           HIGH           True
# 4  03-03-2012       53026  26-02-2012            LOW          False
#
# [5 rows x 23 columns]

# %% [raw]
# # Comparing percentage of profitable orders across customer segments
# by_segment = master_df.groupby('Customer_Segment')
# by_segment.is_profitable.mean()

# %%
# You can also use apply and lambda to alter existing columns
# E.g. you want to see Profit as one decimal place
# apply the round() function 
master_df['Profit'] = master_df['Profit'].apply(lambda x: round(x, 1))
master_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 2  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 3  Ord_2978  Prod_16  SHP_4112  Cust_1088   305.05      0.04              27
# 4  Ord_5484  Prod_16  SHP_7663  Cust_1820   322.82      0.05              35
#
#    Profit  Shipping_Cost  Product_Base_Margin  ... Customer_Segment  \
# 0   -30.5           3.60                 0.56  ...        CORPORATE
# 1  1148.9           2.50                 0.59  ...        CORPORATE
# 2   -47.6           6.15                 0.37  ...        CORPORATE
# 3    23.1           3.37                 0.57  ...      HOME OFFICE
# 4   -17.6           3.98                 0.56  ...         CONSUMER
#
#   Product_Category           Product_Sub_Category Order_ID_x    Ship_Mode  \
# 0  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      36262  REGULAR AIR
# 1       TECHNOLOGY   TELEPHONES AND COMMUNICATION      36262  EXPRESS AIR
# 2  OFFICE SUPPLIES                          PAPER      36262  EXPRESS AIR
# 3  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      37863  REGULAR AIR
# 4  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      53026  REGULAR AIR
#
#     Ship_Date  Order_ID_y  Order_Date Order_Priority  is_profitable
# 0  28-07-2010       36262  27-07-2010  NOT SPECIFIED          False
# 1  27-07-2010       36262  27-07-2010  NOT SPECIFIED           True
# 2  28-07-2010       36262  27-07-2010  NOT SPECIFIED          False
# 3  26-02-2011       37863  24-02-2011           HIGH           True
# 4  03-03-2012       53026  26-02-2012            LOW          False
#
# [5 rows x 23 columns]

# %%
# Creating a column Profit / Order_Quantity
master_df['profit_per_qty'] = master_df['Profit'] / master_df['Order_Quantity']
master_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 2  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 3  Ord_2978  Prod_16  SHP_4112  Cust_1088   305.05      0.04              27
# 4  Ord_5484  Prod_16  SHP_7663  Cust_1820   322.82      0.05              35
#
#    Profit  Shipping_Cost  Product_Base_Margin  ... Product_Category  \
# 0   -30.5           3.60                 0.56  ...  OFFICE SUPPLIES
# 1  1148.9           2.50                 0.59  ...       TECHNOLOGY
# 2   -47.6           6.15                 0.37  ...  OFFICE SUPPLIES
# 3    23.1           3.37                 0.57  ...  OFFICE SUPPLIES
# 4   -17.6           3.98                 0.56  ...  OFFICE SUPPLIES
#
#             Product_Sub_Category Order_ID_x    Ship_Mode   Ship_Date  \
# 0  SCISSORS, RULERS AND TRIMMERS      36262  REGULAR AIR  28-07-2010
# 1   TELEPHONES AND COMMUNICATION      36262  EXPRESS AIR  27-07-2010
# 2                          PAPER      36262  EXPRESS AIR  28-07-2010
# 3  SCISSORS, RULERS AND TRIMMERS      37863  REGULAR AIR  26-02-2011
# 4  SCISSORS, RULERS AND TRIMMERS      53026  REGULAR AIR  03-03-2012
#
#   Order_ID_y  Order_Date Order_Priority is_profitable  profit_per_qty
# 0      36262  27-07-2010  NOT SPECIFIED         False       -1.326087
# 1      36262  27-07-2010  NOT SPECIFIED          True       44.188462
# 2      36262  27-07-2010  NOT SPECIFIED         False       -2.069565
# 3      37863  24-02-2011           HIGH          True        0.855556
# 4      53026  26-02-2012            LOW         False       -0.502857
#
# [5 rows x 24 columns]

# %%
# E.g. Compare average Sales across customer segments
master_df.pivot_table(values = 'Sales', index = 'Customer_Segment', aggfunc = 'mean')
# Out:
#                         Sales
# Customer_Segment
# CONSUMER          1857.859965
# CORPORATE         1787.680389
# HOME OFFICE       1754.312931
# SMALL BUSINESS    1698.124841

# %%
# Grouping by both rows and columns
# Compare the total profit across product categories and customer segments
# Since there are two categorical variables, we use both rows (index) and columns
master_df.pivot_table(values = 'Profit', 
                      index = 'Product_Category', 
                      columns = 'Customer_Segment', 
                      aggfunc = 'sum')
# Out:
# Customer_Segment  CONSUMER  CORPORATE  HOME OFFICE  SMALL BUSINESS
# Product_Category
# FURNITURE          42728.5    22008.3      23978.6         28717.5
# OFFICE SUPPLIES    88532.4   203038.8     121145.6        105306.8
# TECHNOLOGY        156700.1   374701.1     173230.6        181684.1

# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading https://files.pythonhosted.org/packages/ed/39/15045ae46f2a123019aa968dfcba0396c161c20f855f11dea6796bcaae95/PyMySQL-0.9.3-py2.py3-none-any.whl (47kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-0.9.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# reading companies file: throws an error
# companies = pd.read_csv("companies.txt", sep="\t")
# Using encoding = "ISO-8859-1"
companies = pd.read_csv("3_Getting_and_Cleaning_Data\companies.txt", sep="\t", encoding = "ISO-8859-1")
companies.head()
# Out:
#                              permalink                    name  \
# 0                  /Organization/-Fame                   #fame
# 1               /Organization/-Qounter                :Qounter
# 2  /Organization/-The-One-Of-Them-Inc-  (THE) ONE of THEM,Inc.
# 3                /Organization/0-6-Com                 0-6.com
# 4       /Organization/004-Technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
# 2                                  Apps|Games|Mobile  operating          NaN
# 3                                        Curated Web  operating          CHN
# 4                                           Software  operating          USA
#
#   state_code                 region           city  founded_at
# 0         16                 Mumbai         Mumbai         NaN
# 1         DE             DE - Other  Delaware City  04-09-2014
# 2        NaN                    NaN            NaN         NaN
# 3         22                Beijing        Beijing  01-01-2007
# 4         IL  Springfield, Illinois      Champaign  01-01-2010

# %%
import pymysql

# create a connection object 'conn'
conn = pymysql.connect(host="localhost", # your host, localhost for your local machine
                     user="root", # your username, usually "root" for localhost
                      passwd="yourpassword", # your password
                      db="world") # name of the data base; world comes inbuilt with mysql

# create a cursor object c
c = conn.cursor()

# execute a query using c.execute
c.execute("select * from city;")

# getting the first row of data as a tuple
all_rows = c.fetchall()

# to get only the first row, use c.fetchone() instead
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\python\conda\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     582                                 (self.host, self.port), self.connect_timeout,
# --> 583                                 **kwargs)
#     584                             break
#
# C:\python\conda\lib\socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# C:\python\conda\lib\socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-3-5b59f9ff3032> in <module>
#       5                      user="root", # your username, usually "root" for localhost
#       6                       passwd="yourpassword", # your password
# ----> 7                       db="world") # name of the data base; world comes inbuilt with mysql
#       8
#       9 # create a cursor object c
#
# C:\python\conda\lib\site-packages\pymysql\__init__.py in Connect(*args, **kwargs)
#      92     """
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#      96 from . import connections as _orig_conn
#
# C:\python\conda\lib\site-packages\pymysql\connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     323             self._sock = None
#     324         else:
# --> 325             self.connect()
#     326
#     327     def _create_ssl_ctx(self, sslp):
#
# C:\python\conda\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     628                 exc.traceback = traceback.format_exc()
#     629                 if DEBUG: print(exc.traceback)
# --> 630                 raise exc
#     631
#     632             # If e is neither DatabaseError or IOError, It's a bug.
#
# OperationalError: (2003, "Can't connect to MySQL server on 'localhost' ([WinError 10061] No connection could be made because the target machine actively refused it)")

# %%
#scraping data from website
import requests, bs4

# getting HTML from the Google Play web page
url = "https://play.google.com/store/apps/details?id=com.facebook.orca&hl=en"
req = requests.get(url)

# create a bs4 object
# To avoid warnings, provide "html5lib" explicitly
soup = bs4.BeautifulSoup(req.text, "html5lib")

# %%
# getting all the text inside class = "review-body"
reviews = soup.select('.review-body')
print(type(reviews))
print(len(reviews))
print("\n")

# printing an element of the reviews list
print(reviews[6])
# Out:
# <class 'list'>
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-4244db3e2762> in <module>
#       6
#       7 # printing an element of the reviews list
# ----> 8 print(reviews[6])
#
# IndexError: list index out of range

# %%
# step 1: split using </span>
r = reviews[6]
print(type(r))

# r is a bs4 tag, convert it into string to use str.split() 
part1 = str(r).split("</span>")
print(part1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-b3f1e5d2c2a6> in <module>
#       1 # step 1: split using </span>
# ----> 2 r = reviews[6]
#       3 print(type(r))
#       4
#       5 # r is a bs4 tag, convert it into string to use str.split()
#
# IndexError: list index out of range

# %%
import numpy as np
import pandas as pd

# Need requests to connect to the URL, json to convert JSON to dict
import requests, json
import pprint

# joining words in the address by a "+"
add = "UpGrad, Nishuvi building, Anne Besant Road, Worli, Mumbai"
split_address = add.split(" ")
address = "+".join(split_address)
print(address)
# Out:
# UpGrad,+Nishuvi+building,+Anne+Besant+Road,+Worli,+Mumbai

# %%
api_key = "AIzaSyBXrK8md7uaOcpRpaluEGZAtdXS4pcI5xo"

url = "https://maps.googleapis.com/maps/api/geocode/json?address={0}&key={1}".format(address, api_key)
r = requests.get(url)

# The r.text attribute contains the text in the response object
print(type(r.text))
print(r.text)
# Out:
# <class 'str'>
# {
#    "error_message" : "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#    "results" : [],
#    "status" : "REQUEST_DENIED"
# }

# %%
pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading https://files.pythonhosted.org/packages/b4/01/68fcc0d43daf4c6bdbc6b33cc3f77bda531c86b174cac56ef0ffdb96faab/PyPDF2-1.26.0.tar.gz (77kB)
# Building wheels for collected packages: PyPDF2
#   Building wheel for PyPDF2 (setup.py): started
#   Building wheel for PyPDF2 (setup.py): finished with status 'done'
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-cp37-none-any.whl size=61091 sha256=75b0c365f3f015489147c5197dc484712a46a71e0f1c44cca90e8ff8267a1580
#   Stored in directory: C:\Users\Satyakam Rai\AppData\Local\pip\Cache\wheels\53\84\19\35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built PyPDF2
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-1.26.0
# Note: you may need to restart the kernel to use updated packages.
